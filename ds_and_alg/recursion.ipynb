# %%
def fab(n):
    if n == 0:
        return 0
    elif n == 1:
        return 1
    else:
        return fab (n-1) + fab (n-2)

# %%
# def fabi(n):
#     f = lambda k:k if k<2 else fabi(k-1)+fabi(k-2) 
#     return f(n)

# %%
fab(10)
# Out:
# 55
